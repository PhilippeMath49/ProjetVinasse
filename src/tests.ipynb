# %%
import pandas as pd  # Pour les manipulations de données
import numpy as np  # Pour les calculs numériques
import matplotlib.pyplot as plt  # Pour les graphiques
import seaborn as sns  # Pour les visualisations
import geopandas as gpd  # Pour les cartes géographiques
from lib.data import Data
import plotly.express as px

# %%
wineexport1_df = pd.read_csv('data/wineexports/TradeData_2_20_2025_10_30_9.csv', encoding='ISO-8859-1')
wineexport2_df = pd.read_csv('data/wineexports/TradeData_2_20_2025_10_29_8.csv', encoding='ISO-8859-1')
wineexport3_df = pd.read_csv('data/wineexports/TradeData_2_20_2025_10_17_32.csv', encoding='ISO-8859-1')
#typeCode,freqCode,refPeriodId,refYear,refMonth,period,reporterCode,
#|reporterISO|,reporterDesc,flowCode,|flowDesc|,partnerCode,partnerISO,
#|partnerDesc|,partner2Code,partner2ISO,partner2Desc,classificationCode,
#classificationSearchCode,isOriginalClassification,cmdCode,cmdDesc,
# aggrLevel,isLeaf,customsCode,customsDesc,mosCode,motCode,motDesc,
# |qtyUnitCode,qtyUnitAbbr,qty,isQtyEstimated|,altQtyUnitCode,altQtyUnitAbbr,
# altQty,isAltQtyEstimated,netWgt,isNetWgtEstimated,grossWgt,isGrossWgtEstimated,
# cifvalue,fobvalue,primaryValue,legacyEstimationFlag,isReported,isAggregate
wineexport1_df = wineexport1_df.drop(['typeCode', 'freqCode', 'refMonth', 'refYear', 'period', 'reporterCode', 'reporterDesc', 'flowDesc', 'partnerCode','partnerDesc','partner2Code','partner2ISO','partner2Desc','classificationCode', 'classificationSearchCode','cmdDesc','aggrLevel','isLeaf','customsCode','customsDesc','mosCode','motCode','motDesc','qty','isQtyEstimated','altQtyUnitCode','altQtyUnitAbbr','altQty','isAltQtyEstimated','netWgt','isNetWgtEstimated','grossWgt','isGrossWgtEstimated','cifvalue','fobvalue','primaryValue','legacyEstimationFlag','isReported','isAggregate'], axis=1)
wineexport1_df
# Out:
#     refPeriodId reporterISO flowCode      partnerISO  \
# C          2013     Albania   Export           World
# C          2013     Albania   Export          Serbia
# C          2013  Azerbaijan   Export           World
# C          2013  Azerbaijan   Export      Areas, nes
# C          2013   Argentina   Export           World
# ..          ...         ...      ...             ...
# C          2024     Türkiye   Export         Georgia
# C          2024     Türkiye   Export           World
# C          2024     Türkiye   Export  United Kingdom
# C          2024     Türkiye   Export           World
# C          2024     Türkiye   Export         Germany
#
#     isOriginalClassification  \
# C                       2205
# C                       2205
# C                       2205
# C                       2205
# C                       2205
# ..                       ...
# C                       2205
# C                       2205
# C                       2205
# C                       2205
# C                       2205
#
#                                               cmdCode qtyUnitCode  qtyUnitAbbr
# C   Vermouth and other wine of fresh grapes, flavo...           l       2295.0
# C   Vermouth and other wine of fresh grapes, flavo...           l       2295.0
# C   Vermouth and other wine of fresh grapes, flavo...           l       7911.0
# C   Vermouth and other wine of fresh grapes, flavo...           l       7911.0
# C   Vermouth and other wine of fresh grapes, flavo...           l     437219.0
# ..                                                ...         ...          ...
# C   Vermouth and other wine of fresh grapes, flavo...           l         78.0
# C   Vermouth and other wine of fresh grapes, flavo...           l        135.0
# C   Vermouth and other wine of fresh grapes, flavo...           l        135.0
# C   Vermouth and other wine of fresh grapes, flavo...           l       1091.0
# C   Vermouth and other wine of fresh grapes, flavo...           l       1091.0
#
# [25638 rows x 8 columns]

# %%
winexportworld_df = wineexport1_df[wineexport1_df['partnerISO'].str.contains('World', na=False)]

winexportworld_df
# Out:
#     refPeriodId reporterISO flowCode partnerISO  isOriginalClassification  \
# C          2013     Albania   Export      World                      2205
# C          2013  Azerbaijan   Export      World                      2205
# C          2013   Argentina   Export      World                      2205
# C          2013   Australia   Export      World                      2205
# C          2013     Austria   Export      World                      2205
# ..          ...         ...      ...        ...                       ...
# C          2024     Türkiye   Export      World                      2205
# C          2024     Türkiye   Export      World                      2205
# C          2024     Türkiye   Export      World                      2205
# C          2024     Türkiye   Export      World                      2205
# C          2024     Türkiye   Export      World                      2205
#
#                                               cmdCode qtyUnitCode  qtyUnitAbbr
# C   Vermouth and other wine of fresh grapes, flavo...           l       2295.0
# C   Vermouth and other wine of fresh grapes, flavo...           l       7911.0
# C   Vermouth and other wine of fresh grapes, flavo...           l     437219.0
# C   Vermouth and other wine of fresh grapes, flavo...           l     208356.0
# C   Vermouth and other wine of fresh grapes, flavo...           l     636290.0
# ..                                                ...         ...          ...
# C   Vermouth and other wine of fresh grapes, flavo...           l       1398.0
# C   Vermouth and other wine of fresh grapes, flavo...           l        132.0
# C   Vermouth and other wine of fresh grapes, flavo...           l         78.0
# C   Vermouth and other wine of fresh grapes, flavo...           l        135.0
# C   Vermouth and other wine of fresh grapes, flavo...           l       1091.0
#
# [2227 rows x 8 columns]

# %%
wineexport1_df = wineexport1_df[~wineexport1_df['partnerISO'].str.contains('World', na=False)]
wineexport1_df
# Out:
#     refPeriodId reporterISO flowCode                        partnerISO  \
# C          2013     Albania   Export                            Serbia
# C          2013  Azerbaijan   Export                        Areas, nes
# C          2013   Argentina   Export                            Angola
# C          2013   Argentina   Export  Bolivia (Plurinational State of)
# C          2013   Argentina   Export                            Canada
# ..          ...         ...      ...                               ...
# C          2024     Türkiye   Export                        Areas, nes
# C          2024     Türkiye   Export                              Oman
# C          2024     Türkiye   Export                           Georgia
# C          2024     Türkiye   Export                    United Kingdom
# C          2024     Türkiye   Export                           Germany
#
#     isOriginalClassification  \
# C                       2205
# C                       2205
# C                       2205
# C                       2205
# C                       2205
# ..                       ...
# C                       2205
# C                       2205
# C                       2205
# C                       2205
# C                       2205
#
#                                               cmdCode qtyUnitCode  qtyUnitAbbr
# C   Vermouth and other wine of fresh grapes, flavo...           l       2295.0
# C   Vermouth and other wine of fresh grapes, flavo...           l       7911.0
# C   Vermouth and other wine of fresh grapes, flavo...           l       1020.0
# C   Vermouth and other wine of fresh grapes, flavo...           l      17108.0
# C   Vermouth and other wine of fresh grapes, flavo...           l        378.0
# ..                                                ...         ...          ...
# C   Vermouth and other wine of fresh grapes, flavo...           l       1398.0
# C   Vermouth and other wine of fresh grapes, flavo...           l        132.0
# C   Vermouth and other wine of fresh grapes, flavo...           l         78.0
# C   Vermouth and other wine of fresh grapes, flavo...           l        135.0
# C   Vermouth and other wine of fresh grapes, flavo...           l       1091.0
#
# [23411 rows x 8 columns]

# %%
from lib.data import Data
Data.export_data_extraction('data/wineexports/TradeData_2_20_2025_10_30_9.csv', 'data/wineexports/wine_exports_world', 'data/wineexports/wine_exports_1')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 2
#       1 from lib.data import Data
# ----> 2 Data.export_data_extraction('data/wineexports/TradeData_2_20_2025_10_30_9.csv', 'data/wineexports/wine_exports_world', 'data/wineexports/wine_exports_1')
#
# AttributeError: type object 'Data' has no attribute 'export_data_extraction'
